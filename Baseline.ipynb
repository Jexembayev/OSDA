# %%
# !pip install catboost
# Out:
# Collecting catboost
#   Downloading catboost-1.2.2-cp310-cp310-manylinux2014_x86_64.whl (98.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.7/98.7 MB 8.5 MB/s eta 0:00:00
# Requirement already satisfied: graphviz in /usr/local/lib/python3.10/dist-packages (from catboost) (0.20.1)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from catboost) (3.7.1)
# Requirement already satisfied: numpy>=1.16.0 in /usr/local/lib/python3.10/dist-packages (from catboost) (1.23.5)
# Requirement already satisfied: pandas>=0.24 in /usr/local/lib/python3.10/dist-packages (from catboost) (1.5.3)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from catboost) (1.11.4)
# Requirement already satisfied: plotly in /usr/local/lib/python3.10/dist-packages (from catboost) (5.15.0)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from catboost) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24->catboost) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24->catboost) (2023.3.post1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (4.45.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (23.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (3.1.1)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from plotly->catboost) (8.2.3)
# Installing collected packages: catboost
# Successfully installed catboost-1.2.2

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import f1_score, recall_score, accuracy_score, classification_report
from sklearn.model_selection import GridSearchCV, cross_val_score, cross_val_predict
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.linear_model import LogisticRegression
import xgboost as xgb
from catboost import CatBoostClassifier
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import make_scorer, f1_score, accuracy_score, roc_auc_score
# %matplotlib inline
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.impute import SimpleImputer

# %%
df_1 = pd.read_csv('binarized_data_1.csv')
df_2 = pd.read_csv('binarized_data_2 (1).csv')
df_3 = pd.read_csv('binarized_data_3 (1).csv')

# %% [markdown]
# # DataFrame 1

# %%
df_1 = df_1.drop('sample_id', axis=1)
y_feat = 'is_setosa'
df_train, df_test = train_test_split(df_1, train_size=0.7, random_state=0)
X_train, y_train = df_train.drop(y_feat, axis=1), df_train[y_feat]
X_test, y_test = df_test.drop(y_feat, axis=1), df_test[y_feat]
X_train
# Out:
#      sepal_length(4.3, 4.8)  sepal_length(4.8, 5.3)  sepal_length(5.3, 5.8)  \
# 60                    False                    True                   False
# 116                   False                   False                   False
# 144                   False                   False                   False
# 119                   False                   False                   False
# 108                   False                   False                   False
# ..                      ...                     ...                     ...
# 9                     False                    True                   False
# 103                   False                   False                   False
# 67                    False                   False                   False
# 117                   False                   False                   False
# 47                     True                   False                   False
#
#      sepal_length(5.8, 6.3)  sepal_length(6.3, 6.8)  sepal_length(6.8, 7.3)  \
# 60                    False                   False                   False
# 116                   False                    True                   False
# 144                   False                    True                   False
# 119                    True                   False                   False
# 108                   False                    True                   False
# ..                      ...                     ...                     ...
# 9                     False                   False                   False
# 103                   False                    True                   False
# 67                     True                   False                   False
# 117                   False                   False                   False
# 47                    False                   False                   False
#
#      sepal_length(7.3, 7.8)  sepal_length(7.8, 8.3)  sepal_width(2.0, 2.5)  \
# 60                    False                   False                   True
# 116                   False                   False                  False
# 144                   False                   False                  False
# 119                   False                   False                   True
# 108                   False                   False                  False
# ..                      ...                     ...                    ...
# 9                     False                   False                  False
# 103                   False                   False                  False
# 67                    False                   False                  False
# 117                    True                   False                  False
# 47                    False                   False                  False
#
#      sepal_width(2.5, 3.0)  ...  petal_length(4.5, 5.0)  \
# 60                   False  ...                   False
# 116                  False  ...                   False
# 144                  False  ...                   False
# 119                  False  ...                   False
# 108                   True  ...                   False
# ..                     ...  ...                     ...
# 9                    False  ...                   False
# 103                   True  ...                   False
# 67                    True  ...                   False
# 117                  False  ...                   False
# 47                   False  ...                   False
#
#      petal_length(5.0, 5.5)  petal_length(5.5, 6.0)  petal_length(6.0, 6.5)  \
# 60                    False                   False                   False
# 116                   False                    True                   False
# 144                   False                    True                   False
# 119                    True                   False                   False
# 108                   False                    True                   False
# ..                      ...                     ...                     ...
# 9                     False                   False                   False
# 103                   False                    True                   False
# 67                    False                   False                   False
# 117                   False                   False                   False
# 47                    False                   False                   False
#
#      petal_length(6.5, 7.0)  petal_width(0.1, 0.6)  petal_width(0.6, 1.1)  \
# 60                    False                  False                   True
# 116                   False                  False                  False
# 144                   False                  False                  False
# 119                   False                  False                  False
# 108                   False                  False                  False
# ..                      ...                    ...                    ...
# 9                     False                   True                  False
# 103                   False                  False                  False
# 67                    False                  False                   True
# 117                    True                  False                  False
# 47                    False                   True                  False
#
#      petal_width(1.1, 1.6)  petal_width(1.6, 2.1)  petal_width(2.1, 2.6)
# 60                   False                  False                  False
# 116                  False                   True                  False
# 144                  False                  False                   True
# 119                   True                  False                  False
# 108                  False                   True                  False
# ..                     ...                    ...                    ...
# 9                    False                  False                  False
# 103                  False                   True                  False
# 67                   False                  False                  False
# 117                  False                  False                   True
# 47                   False                  False                  False
#
# [105 rows x 30 columns]

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, f1_score

X = X_test
y = y_test

results = {
    'Model': [],
    'Accuracy': [],
    'F1 Score': [],
    'ROC-AUC': []
}

models = {
    'DecisionTree': DecisionTreeClassifier(),
    'RandomForest': RandomForestClassifier(),
    'KNN': KNeighborsClassifier(),
    'NaiveBayes': GaussianNB(),
    'LogisticRegression': LogisticRegression(max_iter=1000),
}

params = {
    'DecisionTree': {'max_depth': [None, 5, 10]},
    'RandomForest': {'n_estimators': [10, 50], 'max_depth': [None, 5]},
    'KNN': {'n_neighbors': [3, 5, 7]},
    'NaiveBayes': {},
    'LogisticRegression': {'C': [0.1, 1, 10]},
}

for name, model in models.items():
    clf = GridSearchCV(model, params[name], cv=5, scoring=make_scorer(f1_score, average='macro'))
    clf.fit(X, y)

    best_model = clf.best_estimator_


    acc_scores = cross_val_score(best_model, X, y, cv=5, scoring='accuracy')
    f1_scores = cross_val_score(best_model, X, y, cv=5, scoring=make_scorer(f1_score, average='macro'))

    predicted_probs = cross_val_predict(best_model, X, y, cv=5, method='predict_proba')[:, 1]
    roc_auc = roc_auc_score(y, predicted_probs)

    results['Model'].append(name)
    results['Accuracy'].append(round(acc_scores.mean(),3))
    results['F1 Score'].append(round(f1_scores.mean(),3))
    results['ROC-AUC'].append(round(roc_auc, 3))

df_results = pd.DataFrame(results)
print(df_results)
# Out:
#                 Model  Accuracy  F1 Score  ROC-AUC
# 0        DecisionTree     0.978     0.932    0.969
# 1        RandomForest     1.000     0.977    1.000
# 2                 KNN     0.978     0.977    1.000
# 3          NaiveBayes     0.956     0.955    0.966
# 4  LogisticRegression     1.000     1.000    1.000

# %% [markdown]
# # DataFrame 2

# %%
df_2 = df_2.drop('sample_id', axis=1)
y_feat = 'stroke'
df_train, df_test = train_test_split(df_2, train_size=0.7, random_state=0)
X_train, y_train = df_train.drop(y_feat, axis=1), df_train[y_feat]
X_test, y_test = df_test.drop(y_feat, axis=1), df_test[y_feat]
X_train
# Out:
#       hypertension  heart_disease  gender_Female  gender_Male  gender_Other  \
# 1921         False          False          False         True         False
# 4074         False          False           True        False         False
# 2311         False          False           True        False         False
# 3080         False          False           True        False         False
# 1620         False          False           True        False         False
# ...            ...            ...            ...          ...           ...
# 4931          True          False           True        False         False
# 3264         False          False           True        False         False
# 1653         False          False          False         True         False
# 2607         False          False          False         True         False
# 2732          True          False           True        False         False
#
#       ever_married_No  ever_married_Yes  work_type_Govt_job  \
# 1921            False              True               False
# 4074            False              True                True
# 2311             True             False               False
# 3080            False              True               False
# 1620            False              True                True
# ...               ...               ...                 ...
# 4931            False              True                True
# 3264            False              True               False
# 1653            False              True               False
# 2607             True             False               False
# 2732            False              True                True
#
#       work_type_Never_worked  work_type_Private  ...  smoking_status_smokes  \
# 1921                   False               True  ...                   True
# 4074                   False              False  ...                  False
# 2311                   False              False  ...                  False
# 3080                   False               True  ...                  False
# 1620                   False              False  ...                  False
# ...                      ...                ...  ...                    ...
# 4931                   False              False  ...                   True
# 3264                   False               True  ...                  False
# 1653                   False               True  ...                   True
# 2607                   False               True  ...                  False
# 2732                   False              False  ...                  False
#
#       age(0-30)  age(30-60)  age(60-90)  avg_glucose_level(55-155)  \
# 1921      False        True       False                       True
# 4074      False       False        True                      False
# 2311       True       False       False                       True
# 3080      False       False        True                       True
# 1620      False       False        True                       True
# ...         ...         ...         ...                        ...
# 4931      False        True       False                       True
# 3264      False       False        True                       True
# 1653      False        True       False                       True
# 2607       True       False       False                       True
# 2732      False        True       False                       True
#
#       avg_glucose_level(155-255)  avg_glucose_level(255-355)  bmi(10-50)  \
# 1921                       False                       False        True
# 4074                        True                       False        True
# 2311                       False                       False        True
# 3080                       False                       False        True
# 1620                       False                       False        True
# ...                          ...                         ...         ...
# 4931                       False                       False        True
# 3264                       False                       False        True
# 1653                       False                       False        True
# 2607                       False                       False        True
# 2732                       False                       False        True
#
#       bmi(50-90)  bmi(90-130)
# 1921       False        False
# 4074       False        False
# 2311       False        False
# 3080       False        False
# 1620       False        False
# ...          ...          ...
# 4931       False        False
# 3264       False        False
# 1653       False        False
# 2607       False        False
# 2732       False        False
#
# [3577 rows x 27 columns]

# %%
models = {
    "Decision Tree": DecisionTreeClassifier(),
    "Random Forest": RandomForestClassifier(),
    "XGBoost": XGBClassifier(),
    "K-Nearest Neighbors": KNeighborsClassifier(),
    "Naive Bayes": GaussianNB(),
    "Logistic Regression": LogisticRegression()
}

X = X_test
y = y_test


results = {
    'Model': [],
    'Accuracy': [],
    'F1 Score': [],
    'ROC-AUC': []
}

models = {
    'DecisionTree': DecisionTreeClassifier(),
    'RandomForest': RandomForestClassifier(),
    'KNN': KNeighborsClassifier(),
    'NaiveBayes': GaussianNB(),
    'LogisticRegression': LogisticRegression(max_iter=1000),
}

params = {
    'DecisionTree': {'max_depth': [None, 5, 10]},
    'RandomForest': {'n_estimators': [10, 50], 'max_depth': [None, 5]},
    'KNN': {'n_neighbors': [3, 5, 7]},
    'NaiveBayes': {},
    'LogisticRegression': {'C': [0.1, 1, 10]},
}

for name, model in models.items():
    clf = GridSearchCV(model, params[name], cv=5, scoring=make_scorer(f1_score, average='macro'))
    clf.fit(X, y)

    best_model = clf.best_estimator_


    acc_scores = cross_val_score(best_model, X, y, cv=5, scoring='accuracy')
    f1_scores = cross_val_score(best_model, X, y, cv=5, scoring=make_scorer(f1_score, average='macro'))

    predicted_probs = cross_val_predict(best_model, X, y, cv=5, method='predict_proba')[:, 1]
    roc_auc = roc_auc_score(y, predicted_probs)

    results['Model'].append(name)
    results['Accuracy'].append(round(acc_scores.mean(),3))
    results['F1 Score'].append(round(f1_scores.mean(),3))
    results['ROC-AUC'].append(round(roc_auc, 3))


df_results = pd.DataFrame(results)
print(df_results)
# Out:
#                 Model  Accuracy  F1 Score  ROC-AUC
# 0        DecisionTree     0.932     0.520    0.473
# 1        RandomForest     0.933     0.504    0.554
# 2                 KNN     0.941     0.494    0.542
# 3          NaiveBayes     0.376     0.319    0.678
# 4  LogisticRegression     0.950     0.487    0.768

# %% [markdown]
# # DataFrame 3

# %%
df_3 = df_3.drop('sample_id', axis=1)
y_feat = 'satisfaction'
df_train, df_test = train_test_split(df_3, train_size=0.7, random_state=0)
X_train, y_train = df_train.drop(y_feat, axis=1), df_train[y_feat]
X_test, y_test = df_test.drop(y_feat, axis=1), df_test[y_feat]
X_train
# Out:
#        Inflight wifi service_high  Departure/Arrival time convenient_high  \
# 87027                       False                                    True
# 60325                       False                                   False
# 58715                       False                                    True
# 64095                       False                                    True
# 3663                         True                                    True
# ...                           ...                                     ...
# 21243                        True                                   False
# 45891                       False                                    True
# 42613                        True                                    True
# 43567                       False                                    True
# 68268                       False                                    True
#
#        Ease of Online booking_high  Gate location_high  Food and drink_high  \
# 87027                        False               False                 True
# 60325                        False               False                False
# 58715                        False               False                False
# 64095                        False                True                False
# 3663                          True                True                False
# ...                            ...                 ...                  ...
# 21243                        False               False                False
# 45891                        False               False                False
# 42613                         True               False                False
# 43567                        False               False                False
# 68268                        False               False                False
#
#        Online boarding_high  Seat comfort_high  Inflight entertainment_high  \
# 87027                 False               True                         True
# 60325                 False              False                        False
# 58715                  True               True                        False
# 64095                 False               True                        False
# 3663                   True              False                        False
# ...                     ...                ...                          ...
# 21243                 False              False                         True
# 45891                  True               True                         True
# 42613                  True              False                        False
# 43567                  True               True                         True
# 68268                 False              False                        False
#
#        On-board service_high  Leg room service_high  ...  Gender_Male  \
# 87027                  False                   True  ...         True
# 60325                  False                  False  ...         True
# 58715                  False                  False  ...        False
# 64095                   True                  False  ...         True
# 3663                   False                   True  ...        False
# ...                      ...                    ...  ...          ...
# 21243                   True                   True  ...        False
# 45891                   True                   True  ...         True
# 42613                   True                   True  ...         True
# 43567                   True                  False  ...        False
# 68268                   True                   True  ...        False
#
#        Customer Type_Loyal Customer  Customer Type_disloyal Customer  \
# 87027                          True                            False
# 60325                          True                            False
# 58715                          True                            False
# 64095                          True                            False
# 3663                           True                            False
# ...                             ...                              ...
# 21243                          True                            False
# 45891                          True                            False
# 42613                          True                            False
# 43567                          True                            False
# 68268                          True                            False
#
#        Type of Travel_Business travel  Type of Travel_Personal Travel  \
# 87027                           False                            True
# 60325                            True                           False
# 58715                           False                            True
# 64095                           False                            True
# 3663                            False                            True
# ...                               ...                             ...
# 21243                            True                           False
# 45891                            True                           False
# 42613                           False                            True
# 43567                           False                            True
# 68268                           False                            True
#
#        Class_Business  Class_Eco  Class_Eco Plus  Departure_Delay_30min  \
# 87027           False       True           False                  False
# 60325           False       True           False                  False
# 58715           False       True           False                  False
# 64095           False       True           False                  False
# 3663            False       True           False                  False
# ...               ...        ...             ...                    ...
# 21243           False       True           False                  False
# 45891            True      False           False                  False
# 42613           False       True           False                  False
# 43567           False       True           False                  False
# 68268           False       True           False                  False
#
#        Arrival_Delay_30min
# 87027                False
# 60325                False
# 58715                False
# 64095                False
# 3663                 False
# ...                    ...
# 21243                False
# 45891                False
# 42613                False
# 43567                False
# 68268                False
#
# [62232 rows x 43 columns]

# %%
X = X_test
y = y_test

results = {
    'Model': [],
    'Accuracy': [],
    'F1 Score': [],
    'ROC-AUC': []
}

models = {
    'DecisionTree': DecisionTreeClassifier(),
    'RandomForest': RandomForestClassifier(),
    'KNN': KNeighborsClassifier(),
    'NaiveBayes': GaussianNB(),
    'LogisticRegression': LogisticRegression(max_iter=1000),
}

params = {
    'DecisionTree': {'max_depth': [None, 5, 10]},
    'RandomForest': {'n_estimators': [10, 50], 'max_depth': [None, 5]},
    'KNN': {'n_neighbors': [3, 5, 7]},
    'NaiveBayes': {},
    'LogisticRegression': {'C': [0.1, 1, 10]},
}

for name, model in models.items():
    clf = GridSearchCV(model, params[name], cv=5, scoring=make_scorer(f1_score, average='macro'))
    clf.fit(X, y)

    best_model = clf.best_estimator_


    acc_scores = cross_val_score(best_model, X, y, cv=5, scoring='accuracy')
    f1_scores = cross_val_score(best_model, X, y, cv=5, scoring=make_scorer(f1_score, average='macro'))


    predicted_probs = cross_val_predict(best_model, X, y, cv=5, method='predict_proba')[:, 1]
    roc_auc = roc_auc_score(y, predicted_probs)

    results['Model'].append(name)
    results['Accuracy'].append(round(acc_scores.mean(),3))
    results['F1 Score'].append(round(f1_scores.mean(),3))
    results['ROC-AUC'].append(round(roc_auc, 3))

df_results = pd.DataFrame(results)
print(df_results)
# Out:
#                 Model  Accuracy  F1 Score  ROC-AUC
# 0        DecisionTree     0.898     0.896    0.941
# 1        RandomForest     0.896     0.894    0.954
# 2                 KNN     0.892     0.890    0.941
# 3          NaiveBayes     0.811     0.811    0.894
# 4  LogisticRegression     0.894     0.892    0.944
